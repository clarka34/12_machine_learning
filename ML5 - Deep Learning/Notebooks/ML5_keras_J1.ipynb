# %% [markdown]
# # First Deep Learning Project in Python with Keras

# %% [markdown]
# The steps we are going to cover:
# 1. Dependancies installation
# 2. Load Data.
# 3. Define Keras Model.
# 4. Compile Keras Model.
# 5. Fit Keras Model.
# 6. Evaluate Keras Model.
# 7. Put It All Together.
# 8. Make Predictions

# %% [markdown]
# ## Dependancies installation

# %%
try:
    import google.colab
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    # Installer toutes les librairies nécessaires
    # !pip install tensorflow numpy pandas scikit-learn matplotlib seaborn
else:
    print("""In the environment you created for this module, install the required dependencies.
For example:
    conda create --name ML5 python=3.11
    conda activate ML5
    conda install jupyter tensorflow numpy pandas scikit-learn matplotlib seaborn""")
# Out:
# In the environment you created for this module, install the required dependencies.
# For example:
#     conda create --name ML5 python=3.11
#     conda activate ML5
#     conda install jupyter tensorflow numpy pandas scikit-learn matplotlib seaborn

# %% [markdown]
# ## Load Data

# %%
if IN_COLAB:
  from google.colab import files
  uploaded = files.upload()

# %% [markdown]
# Download the dataset and place it in your local working directory, the same location as your python file. Take a look at the dataset:

# %%
import pandas as pd
df = pd.read_csv('../Data/housepricedata.csv')

# %% [markdown]
# Here, you can explore the data a little. We have our input features in the first ten columns:
#
# - Lot Area (in sq ft)
# - Overall Quality (scale from 1 to 10)
# - Overall Condition (scale from 1 to 10)
# - Total Basement Area (in sq ft)
# - Number of Full Bathrooms
# - Number of Half Bathrooms
# - Number of Bedrooms above ground
# - Total Number of Rooms above ground
# - Number of Fireplaces
# - Garage Area (in sq ft)
#
# In our last column, we have the feature that we would like to predict:
# - Is the house price above the median or not? (1 for yes and 0 for no)
#
# Which task are we going to train the neural network for (regression, classification, other...) ?

# %%
# from skrub import TableReport

# TableReport(df)

# %% [markdown]
# # Your answer here :
# classification since we want to predict either 0 or 1

# %% [markdown]
# Now that we’ve seen what our data looks like, we want to convert it into arrays for our machine to process:

# %%
dataset = df.values

# %% [markdown]
# Split the dataset into input features (X) and the feature we wish to predict (Y). To do that split, assign the first 10 columns of our array to a variable called X and the last column of our array to a variable called Y

# %%
X = dataset[:,0:10]
y = dataset[:,10]

# %%
1241*.1765
# Out:
# 219.0365

# %% [markdown]
# Now, we want to split our dataset into a training set, a validation set and a test set. These are the dimensions you need to get for your train, validation and test datasets: (1022, 10) (219, 10) (219, 10) (1022,) (219,) (219,)
#
# We will use the code from scikit-learn called ‘train_test_split’, which as the name suggests, split our dataset into a training set and a test set. We first import the code we need:

# %%
# splitting into train and test
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=1022, random_state=34)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (1022, 10) (438, 10) (1022,) (438,)

# %% [markdown]
# Unfortunately, this function only helps us split our dataset into two. Since we want a separate validation set and test set, we can use the same function to do the split again on val_and_test:

# %%
# splitting into validation and test
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=219, random_state=34)
print(X_train.shape, X_val.shape, X_test.shape, y_train.shape, y_val.shape, y_test.shape)
# Out:
# (1022, 10) (219, 10) (219, 10) (1022,) (219,) (219,)

# %% [markdown]
# Feature scaling will help us see all the variables from the same scale, it will also help our models learn faster

# %%
# scaling
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Define Keras Model.

# %% [markdown]
# The first thing we have to do is to set up the architecture. Let’s first think about what kind of neural network architecture we want. Suppose we want this neural network:
# ![ex_rnn_keras.PNG](attachment:ex_rnn_keras.PNG)
# In words, we want to have these layers:
#
# - Hidden layer 1: 12 neurons, ReLU activation
# - Hidden layer 2: 16 neurons, ReLU activation
# - Output Layer: 1 neuron, Sigmoid activation
#
# Now, we need to describe this architecture to Keras. We will be using the Sequential model, which means that we merely need to describe the layers above in sequence.

# %%
# Dependencies
import keras
from keras.models import Sequential
from keras.layers import Dense

# define model
model = Sequential(name='sequential_house_price')
# model.add(keras.Input(shape=(12,)))
model.add(Dense(12, activation='relu', name='layer1'))
model.add(Dense(16, activation='relu', name='layer2'))
# model.add(Dense(4, activation='relu', name='layer3'))
model.add(Dense(1, activation='sigmoid', name='layer4'))
# Out:
# 2025-10-21 17:05:35.998344: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.summary()
# Out:
# Model: "sequential_house_price"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ layer1 (Dense)                  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer2 (Dense)                  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer4 (Dense)                  │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.layers
# Out:
# [<Dense name=layer1, built=False>,
#  <Dense name=layer2, built=False>,
#  <Dense name=layer4, built=False>]

# %% [markdown]
# Now that the model is defined, we can compile it.
#
# Compiling the model uses TensorFlow that chooses the best way to represent the network for training and making predictions to run on your hardware, such as CPU or GPU or even distributed.

# %%
# compile model
model.compile(loss='mean_squared_error', optimizer='SGD', metrics=['accuracy'])

# %% [markdown]
# We have defined our model and compiled it ready for efficient computation.
#
# Now it is time to execute the model on some data (use 100 iterations and 32 batch size).

# %%
# train model
# fit the keras model on the dataset
model.fit(X_train_scaled, y_train, epochs=100, batch_size=32, verbose=0)

# %%
# predict on validation set
y_val_pred = model.predict(X_val_scaled)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
# calculate accuracy on validation set
_, accuracy = model.evaluate(X_val_scaled, y_val)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8767 - loss: 0.0835
# Accuracy: 87.67

# %% [markdown]
# We have trained our model, which gives us a correct accuracy. But we haven't used our validation set properly, and our test set at all. Let's correct that.

# %%
# train model
from keras.callbacks import EarlyStopping

# early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(X_train_scaled, y_train, 
                    epochs=100, 
                    batch_size=32, 
                    validation_data=(X_val_scaled, y_val), 
                    validation_freq=1)
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9031 - loss: 0.0702 - val_accuracy: 0.8767 - val_loss: 0.0834
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9031 - loss: 0.0700 - val_accuracy: 0.8767 - val_loss: 0.0833
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9031 - loss: 0.0699 - val_accuracy: 0.8767 - val_loss: 0.0832
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9031 - loss: 0.0698 - val_accuracy: 0.8767 - val_loss: 0.0831
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9022 - loss: 0.0697 - val_accuracy: 0.8767 - val_loss: 0.0831
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9041 - loss: 0.0695 - val_accuracy: 0.8767 - val_loss: 0.0830
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9051 - loss: 0.0694 - val_accuracy: 0.8767 - val_loss: 0.0829
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9051 - loss: 0.0692 - val_accuracy: 0.8767 - val_loss: 0.0829
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9051 - loss: 0.0691 - val_accuracy: 0.8767 - val_loss: 0.0828
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9051 - loss: 0.0690 - val_accuracy: 0.8767 - val_loss: 0.0827
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9051 - loss: 0.0689 - val_accuracy: 0.8767 - val_loss: 0.0827
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9051 - loss: 0.0688 - val_accuracy: 0.8767 - val_loss: 0.0826
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9051 - loss: 0.0686 - val_accuracy: 0.8767 - val_loss: 0.0825
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9051 - loss: 0.0685 - val_accuracy: 0.8721 - val_loss: 0.0825
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9051 - loss: 0.0684 - val_accuracy: 0.8721 - val_loss: 0.0824
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9051 - loss: 0.0683 - val_accuracy: 0.8721 - val_loss: 0.0824
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9051 - loss: 0.0682 - val_accuracy: 0.8721 - val_loss: 0.0823
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9051 - loss: 0
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9100 - loss: 0.0643 - val_accuracy: 0.8767 - val_loss: 0.0804
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9100 - loss: 0.0642 - val_accuracy: 0.8767 - val_loss: 0.0804
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9100 - loss: 0.0642 - val_accuracy: 0.8767 - val_loss: 0.0804
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9100 - loss: 0.0641 - val_accuracy: 0.8767 - val_loss: 0.0804
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9090 - loss: 0.0641 - val_accuracy: 0.8767 - val_loss: 0.0804
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9090 - loss: 0.0640 - val_accuracy: 0.8767 - val_loss: 0.0803
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9100 - loss: 0.0639 - val_accuracy: 0.8767 - val_loss: 0.0803
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9100 - loss: 0.0639 - val_accuracy: 0.8767 - val_loss: 0.0803
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9100 - loss: 0.0638 - val_accuracy: 0.8767 - val_loss: 0.0803
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9100 - loss: 0.0638 - val_accuracy: 0.8767 - val_loss: 0.0803
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9100 - loss: 0.0637 - val_accuracy: 0.8767 - val_loss: 0.0803
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9110 - loss: 0.0637 - val_accuracy: 0.8767 - val_loss: 0.0802
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9110 - loss: 0.0636 - val_accuracy: 0.8767 - val_loss: 0.0802
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9100 - loss: 0.0635 - val_accuracy: 0.8767 - val_loss: 0.0802
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9100 - loss: 0.0635 - val_accuracy: 0.8767 - val_loss: 0.0801
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9100 - loss: 0.0634 - val_accuracy: 0.8767 - val_loss: 0.0801
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9110 - loss: 0.0634 - val_accuracy: 0.8767 - val_loss: 0.0801
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9110 - loss: 0.0633 - val_accuracy: 0.8767 - val_loss: 0.0801
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9100 - loss: 0.0633 - val_accuracy: 0.8767 - val_loss: 0.0801
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9110 - loss: 0.0632 - val_accuracy: 0.8767 - val_loss: 0.0800
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9110 - loss: 0.0632 - val_accuracy: 0.8767 - val_loss: 0.0800
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9100 - loss: 0.0631 - val_accuracy: 0.8767 - val_loss: 0.0800
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9119 - loss: 0.0631 - val_accuracy: 0.8767 - val_loss: 0.0800
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9129 - loss: 0.0630 - val_accuracy: 0.8767 - val_loss: 0.0800
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9119 - loss: 0.0630 - val_accuracy: 0.8767 - val_loss: 0.0800
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9119 - loss: 0.0629 - val_accuracy: 0.8767 - val_loss: 0.0799
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9119 - loss: 0.0629 - val_accuracy: 0.8767 - val_loss: 0.0799
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9129 - loss: 0.0628 - val_accuracy: 0.8767 - val_loss: 0.0799
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9129 - loss: 0.0628 - val_accuracy: 0.8767 - val_loss: 0.0799
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9119 - loss: 0.0627 - val_accuracy: 0.8767 - val_loss: 0.0799
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.0627 - val_accuracy: 0.8767 - val_loss: 0.0799
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.0626 - val_accuracy: 0.8767 - val_loss: 0.0799
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9129 - loss: 0.0626 - val_accuracy: 0.8767 - val_loss: 0.0799
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9129 - loss: 0.0625 - val_accuracy: 0.8767 - val_loss: 0.0798
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9129 - loss: 0.0625 - val_accuracy: 0.8767 - val_loss: 0.0798
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9139 - loss: 0.0624 - val_accuracy: 0.8767 - val_loss: 0.0798
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9129 - loss: 0.0624 - val_accuracy: 0.8767 - val_loss: 0.0798
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9129 - loss: 0.0624 - val_accuracy: 0.8767 - val_loss: 0.0798

# %%
# predict on TEST set
y_test_pred = model.predict(X_test_scaled)

# calculate accuracy on test set
_, accuracy = model.evaluate(X_test_scaled, y_test)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9361 - loss: 0.0540
# Accuracy: 93.61

# %% [markdown]
# Visualize training and validation losses and accuracies plots with the help of keras

# %%
# visualize training and validation accuracies
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8,6))
ax.plot(history.history['accuracy'])
ax.plot(history.history['val_accuracy'])
ax.set_title('model accuracy')
ax.set_ylabel('accuracy')
ax.set_xlabel('epoch')
# ax.set_ylim([0,1])
fig.legend(['train', activation='rel'val'])
plt.show()

# %%
# visualize training and validation losses
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(history.history['loss'])
ax.plot(history.history['val_loss'])
ax.set_title('model loss')
ax.set_ylabel('loss')
ax.set_xlabel('epoch')
# ax.set_ylim([0, 1])
fig.legend(['train', 'val'])
plt.show()

# %% [markdown]
# We have trained our neural network on the entire dataset and we can evaluate the performance of the network on the same dataset. A list of most hyperparameters available keras:

# %% [markdown]
# https://keras.io/api/layers/initializers/
#
# https://keras.io/api/layers/activations/
#
# https://keras.io/api/losses/
#
# https://keras.io/api/optimizers/
